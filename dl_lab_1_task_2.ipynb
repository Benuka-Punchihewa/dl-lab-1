# %% [markdown]
# <a href="https://colab.research.google.com/github/Benuka-Punchihewa/dl-lab-1/blob/main/dl_lab_1_task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas for managing datasets
import pandas as pd

# %%
# read csv file
df = pd.read_csv('Au_nanoparticle_dataset.csv')

df.head()
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 1   2  273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 2   3  273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 3   4  273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 4   5  273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
# 1  24.1755  ...         0         0         0         0         0         0
# 2  31.0305  ...         0         0         0         0         0         0
# 3  37.8795  ...         0         0         0         0         0         0
# 4  39.7614  ...         0         0         0         0         0         0
#
# ...

# %%
# Drop unwanted columns
new_df = df.filter(items = ["N_total", "N_bulk", "N_surface", "R_avg"], axis = 1)

new_df.head(20)
# Out:
#     N_total  N_bulk  N_surface    R_avg
# 0      1599    1014        585  17.3706
# 1      1642    1034        608  17.6061
# 2      4637    3365       1272  25.3692
# 3      7189    5292       1897  29.7011
# 4     11004    8508       2496  34.2831
# 5     13375   10768       2607  36.6334
# 6     13795   11155       2640  37.0108
# 7     13947   11304       2643  37.1672
# 8     14020   11357       2663  37.2103
# 9     14056   11389       2667  37.2467
# 10     1534     966        568  17.1107
# 11     1559     974        585  17.2101
# 12     4356    3099       1257  24.8253
# 13     6550    4675       1875  29.0376
# 14    10175    7748       2427  33.4399
# 15    12393    9842       2551  35.6950
# 16    13207   10590       2617  36.4657
# 17    13543   10937       2606  36.7871
# 18    13713   11079       2634  36.9333
# 19    13791   11151       2640  37.0104

# %%
mean = new_df['N_total'].mean()
standard_deviation = new_df['N_total'].std()
q1 = new_df['N_total'].quantile(0.25)
q2 = new_df['N_total'].quantile(0.50)
q3 = new_df['N_total'].quantile(0.75)

print(f"Mean of N_total: {mean}")
print(f"Standard deviation of N_total: {standard_deviation}")
print(f"First quartile of N_total: {q1}")
print(f"Second quartile of N_total: {q2}")
print(f"Third quartile of N_total: {q3}")
# Out:
# Mean of N_total: 3476.7865
# Standard deviation of N_total: 3679.286769157872
# First quartile of N_total: 1061.0
# Second quartile of N_total: 1867.0
# Third quartile of N_total: 4503.0

# %%
mean = new_df['N_bulk'].mean()
standard_deviation = new_df['N_bulk'].std()
q1 = new_df['N_bulk'].quantile(0.25)
q2 = new_df['N_bulk'].quantile(0.50)
q3 = new_df['N_bulk'].quantile(0.75)

print(f"Mean of N_bulk: {mean}")
print(f"Standard deviation of N_bulk: {standard_deviation}")
print(f"First quartile of N_bulk: {q1}")
print(f"Second quartile of N_bulk: {q2}")
print(f"Third quartile of N_bulk: {q3}")
# Out:
# Mean of N_bulk: 2521.55025
# Standard deviation of N_bulk: 2976.232458728154
# First quartile of N_bulk: 618.75
# Second quartile of N_bulk: 1199.0
# Third quartile of N_bulk: 3183.0

# %%
mean = new_df['N_surface'].mean()
standard_deviation = new_df['N_surface'].std()
q1 = new_df['N_surface'].quantile(0.25)
q2 = new_df['N_surface'].quantile(0.50)
q3 = new_df['N_surface'].quantile(0.75)

print(f"Mean of N_surface: {mean}")
print(f"Standard deviation of N_surface: {standard_deviation}")
print(f"First quartile of N_surface: {q1}")
print(f"Second quartile of N_surface: {q2}")
print(f"Third quartile of N_surface: {q3}")
# Out:
# Mean of N_surface: 955.23625
# Standard deviation of N_surface: 721.870220392634
# First quartile of N_surface: 437.0
# Second quartile of N_surface: 666.0
# Third quartile of N_surface: 1301.75

# %%
mean = new_df['R_avg'].mean()
standard_deviation = new_df['R_avg'].std()
q1 = new_df['R_avg'].quantile(0.25)
q2 = new_df['R_avg'].quantile(0.50)
q3 = new_df['R_avg'].quantile(0.75)

print(f"Mean of R_avg: {mean}")
print(f"Standard deviation of R_avg: {standard_deviation}")
print(f"First quartile of R_avg: {q1}")
print(f"Second quartile of R_avg: {q2}")
print(f"Third quartile of R_avg: {q3}")
# Out:
# Mean of R_avg: 20.654363375
# Standard deviation of R_avg: 7.6107159585417135
# First quartile of R_avg: 15.160725
# Second quartile of R_avg: 18.62925
# Third quartile of R_avg: 25.525125000000003

# %%
import matplotlib.pyplot as plt

# Create a 1x4 layout for histograms
fig, axes = plt.subplots(1, 4, figsize=(15, 5))

# Plot histograms for each feature
df['N_total'].plot.hist(ax=axes[0], bins=10, edgecolor='black')
axes[0].set_title('N_total')

df['N_bulk'].plot.hist(ax=axes[1], bins=10, edgecolor='black')
axes[1].set_title('N_bulk')

df['N_surface'].plot.hist(ax=axes[2], bins=10, edgecolor='black')
axes[2].set_title('N_surface')

df['R_avg'].plot.hist(ax=axes[3], bins=10, edgecolor='black')
axes[3].set_title('R_avg')
# Out:
# Text(0.5, 1.0, 'R_avg')

# %%
import seaborn as sns

# Create a pairplot
sns.pairplot(new_df)

# Show the plot
plt.show()

# %%
g = sns.PairGrid(new_df)

# Diagonal plots with histogram and kde
g.map_diag(sns.histplot, kde=True)

# Upper triangle with bivariate histogram
g.map_upper(sns.histplot, bins=10, cbar=True)

# Lower triangle with bivariate kde
g.map_lower(sns.kdeplot, cmap='Blues_d')

# Show the plot
plt.show()
